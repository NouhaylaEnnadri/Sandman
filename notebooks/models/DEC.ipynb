# %%
# =========================
# CONFIG — EDIT THESE
# =========================

DATA_DIR = "."         # folder with your CSVs
PFC_FILE = "PFC1.csv"
HPC_FILE = "HPC1.csv"
EMG_FILE = "EMG1.csv"

CSV_HAS_HEADER = False # set True if your CSVs have headers
CSV_VALUE_COL  = 0     # column name or index for the signal column

FS_HZ      = 256       # sampling rate (Hz)
WINDOW_SEC = 5.0
STEP_SEC   = 2.5       # 50% overlap

# Spectrogram parameters
N_PER_SEG   = 256
N_OVERLAP   = 192
FREQ_MAX_HZ = 125      # max frequency to keep

# DEC / clustering
N_CLUSTERS = 6         # >4 to allow extra micro-states (tune: 5–10)
LATENT_DIM = 16        # dimension of latent space (embedding size)

# Training
BATCH_SIZE   = 64
AE_EPOCHS    = 15      # pretrain autoencoder
DEC_EPOCHS   = 30      # refine clusters
LR_AE        = 1e-3
LR_DEC       = 1e-3
WEIGHT_DECAY = 1e-5

DEVICE = "cuda"  # "cuda" or "cpu" (auto-adjust below)

SEED = 42

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from scipy import signal
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import random

# device
if DEVICE == "cuda" and not torch.cuda.is_available():
    DEVICE = "cpu"
print("Using device:", DEVICE)

def set_seed(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(SEED)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 6
#       3 import matplotlib.pyplot as plt
#       4 from pathlib import Path
# ----> 6 import torch
#       7 import torch.nn as nn
#       8 from torch.utils.data import Dataset, DataLoader
#
# File c:\Users\lenovo\Sandman\.sandman\Lib\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
#     288     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     289     # path/lib_folder/lib
#
# ...
